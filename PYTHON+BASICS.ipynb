# %%
# Strings

# define a string
def execute_strng(a,b):

    print("############ STRINGS ARE IMMUTABLE ##############")
    print("1. String:",a)

# slice , start at position 2 and go upto 4 but not including 4
    print("2. a[2:4]-->",a[2:4])

# start at position 2 and go upto 7 in increments of 2
    print("3. a[2:7:2]-->",a[2:7:2])

# Reverse the string
    print("4. a[::-1]-->",a[::-1])

# length
    print("5. length of string:", len(a))

# read in reverse
    print("6. read last letter:",a[-1])

# concatenation
    print("7. concatenated strings: ",a[6:]+", "+b)

# string operation
    print("8. string operation-->Awe*10:", b[:3]*10)

# string methods
    print("9. Upper: ",a.upper())
    print("10. lower:",a.lower())


# string to list based on split
    mystr = "hello world"
    print("11. based on space, mystr.split()-->",mystr.split())

# format the float values
    result=100/7
    print("12. float formatting-->value {r:1.3f}".format(r=result))

# print formats
    print("13.  .format print output", "The {} {} {}".format('fix','brow','quick'))
    name="Sam"
    print("14. f format print-->",f"His name is {name}")

########################################################################

def execute_list(mylist1,mylist2):

    print("\n############ LIST ARE MUTABLE ##############")

    print("1. list can have mixed data types-->",mylist2)

    print('2. numbers list-->',mylist1)

    # length of the list
    print("3. length of the list-->", len(mylist1))

    # List indexing and slicing is similar to string
    print("4. list indexing mylist[1:]-->", mylist1[1:])

    # Concatenation
    print("5. Concatenating mylist1+mylist2-->",mylist1+mylist2)

    # append
    mylist1.append(0)
    print("6. append to mylist1.append(4)-->",mylist1)

    # pop from the last position, you can speccify the position from where you want to pop
    # example mylist1.pop(0)
    mylist1.pop()
    print("7. pop from last position-->", mylist1)

    # sort the list
    mylist1.sort()
    print("8. sorted the list-->",mylist1)

    # List is mutable, meaning you can do assignment
    new_list=mylist1
    new_list[1]=6
    print("9. list reassignment-->",new_list)

########################################################################

def execute_dict (d1,d2):

    print("\n ###################### DICIONARY ############################")
    print("1. Dictionary are unordered\n2. Dictionary cannot be sorted")

    # print dictionary
    print("3. dictionary-->",d1)

    # retrieve based on key
    print("4. key1 values is-->",d1['key1'])

    # dictionary d2
    print("5. Dictionary d2-->",d2)

    # Retrince from d2
    print("6. Retrience hi from d2-->", d2['k1'][0])

    # Retrince from d2
    print("7. Retieve and do upper on a word in a dictionary-->", d2['k1'][0].upper())

    # Adding a key-value to the dictionary
    d1['key3']=3
    print("8. Add key-value to dictionary-->",d1)

    # Overwrite the value in a dictionary
    d1['key3'] = 'NEW VALUE'
    print("9. Overwrite the value in a dictionary-->", d1)

    # To see only all keys in a dictionary
    print("10. All key in a dictionary are-->",d1.keys())

    # To see only all values in a dictionary
    print("10. All Values in a dictionary are-->", d1.values())

    # To see all items in a dictionary
    print("10. All items in a dictionary are (tuples pair)-->", d1.items())

########################################################################

def execute_tuples (t):

    print("\n ###################### TUPLES ############################")
    print("1. TUPLES are immutable (means you can't reassign values in a tuple)")

    # display the tuple
    print("2. tuple example-->",t)

    #length
    print("3. length of a tuple-->",len(t))

    # Mixed data type inside a tuple:
    t1=('one',2,['three',4])
    print("4. Mixed data types can exist in tuple-->",t1)

    # Indexing and slicing allowed just like list
    print("5. Indexing in tuple--> ",t[::-1])

    # Index method in tuples
    print("6. Index of 3 inside tuple-->",t.index(3))

    # Count method
    t3=('a','a',2)
    print("7. count method to find count of an object inside the tuple ('a','a',2)-->",t3.count('a'))

########################################################################

def execute_sets ():

    print("\n ###################### SETS ############################")
    print("1. SETS are unordered collections of unique elements")

    # define the set
    print("2. Define set using (myset=set())")
    myset = set()

    # Add to set
    print("3. Add elements to set using add method")
    myset.add(1)
    myset.add(2)
    myset.add(3)
    myset.add(4)
    myset.add('a')

    # display the set
    print("4. display the set-->",myset)

    mylist=[1,1,1,2,2,2,3,3,3,4,4,]
    print("5. my list-->",mylist)

    print("6. using set we can unique values",set(mylist))


# Python comparison operators
def execute_operators():

    print("\n ###################### OPERATORS ############################")
    print("1. equality operators 2==2 -->", 2==2)
    print("2. not equality 3!=3 --> ", 3!=3)
    print("3. greater than 1>2 --> ",1>2)
    print("4. less than 1<2 --> ",1<2)
    print("5. Logical operators 1<2 and 1<3 --> ", (1<2 and 1<3))
    print("6. Logical operators 1<2 or 2>3 --> ", (1<2 or 1 < 3))
    print("7. Logical operators not 1<2 --> ", not 1 < 2)



# Control flow in Python
def control_flow(a,k,b,c):
    print("\n############ CONTROL FLOW ##############")

    # if elif and else statements
    loc='Bank'
    if loc =='Auto Shop':
        print("1. if elif and else statements flow--> Cars are cool")
    elif loc=='Bank':
        print("1. if elif and else statements flow--> Awesome Bank")
    else:
        print("1. if elif and else statements flow--> give better input")

    # For loop
    mylist=[1,2,3,4,5,6]
    print("\nlist -->",mylist)
    print("2. For loop with list and if to find even and odd")
    list2=[]
    for num in mylist:
        if num%2==0:
            list2.append("Even No.")
        else:
            list2.append("Odd No.")
    print(list2)

    # string with for
    str="Hello World"
    print("\nString --> ", str)
    print("2. for loop with string")
    for letter in str:
        print(letter)

    # Tuple with for
    tup=(1,2,3)
    print("\nTuple --> ", tup)
    print("3. Tuple with for loop")
    for item in tup:
        print(item)

    mylist=[(1,2),(3,4),(5,6)]
    print("Tuple Unpacking")
    print("list-->",mylist)
    for (a,b) in mylist:
        print(a)
        print(b)

    # Dictionary with For loop
    d = {'k1': 1, 'k2': 2, 'k3': 3}
    print("\nDictionary --> ", d)
    print("4. for loop with Dictionary")
    print("\nkey-value pairs")
    for x,y in d.items():
        print(x,y)
    print("values only output : ")
    for x in d.values():
        print(x)
    print("Keys only output : ")
    for x in d.keys():
        print(x)

    # While
    print("\n5. While ")
    x=0
    while(x<3):
        print("value of x=",x)
        x=x+1

    # break, continue and pass

    print("\n6. break example")
    mystring="hello"
    for x in mystring:
        if x=='l':
            break
        else:
            print(x)


    print("\n7. continue example")
    for x in mystring:
        if x == 'l':
            continue
        else:
            print(x)

    print("\n8. pass example")
    for x in mystring:
        if x == 'l':
            pass
        else:
            print(x)

    print("\n9. Useful Operators")
    print("\nA).range")
    for num in range(0,11,2):
        print(num)

    print("\nB).enumerate")
    word='abcde'
    for item in enumerate(word):
        print(item)
    for index,letter in enumerate(word):
        print("index=",index)
        print("letter=",letter)

    print("\nC).zip")
    mylist1=['a','b','c']
    mylist2=[100,200,300]
    print("list1=",mylist1)
    print("list2=",mylist2)
    for item in zip(mylist1,mylist2):
        print(item)

    print("\nC).In")
    print("x in ['x','y','z']-->",'x' in ['x','y','z'])
    print("mykey in {'mykey':345} -->",'mykey' in {'mykey':345})

    print("\nD). random")
    from random import randint
    print("randit(0,100)-->",randint(0,100))

    print("\nE).user input")
    result=input("favorite number:")
    print(result)

# list comprehension
def execute_listcomprehension():

    print("\nlist comprehension\n")
    str='hello'
    mylist=[mylist for mylist in str]
    print("String-->",str)
    print("[mylist for mylist in str]-->",mylist)

    print("\nSquare of only even numbers in a list(0,11)")
    print([x**2 for x in range(0,11) if x%2==0])




  # print ("for loop output of [(1,2),(3,4)]: ")
  #   for x,y in a:
  #       print(x)
  #   print("key-values output : ")
  #   for x,y in k.items():
  #       print(x,y)
  #   print("values only output : ")
  #   for x in k.values():
  #       print(x)
  #   print("output of range(2,5) in for loop: ")
  #   for i in range(b[0],b[1]):
  #       print(i)
  #   print("output of range(2,8,2) in for loop (increment of 2): ")
  #   for i in range(c[0],c[1],c[2]):
  #       print(i)

# %%
# This is a sample Python script.

# Press Shift+F10 to execute it or replace it with your code.
# Press Double Shift to search everywhere for classes, files, tool windows, actions, and settings.
# from Basics import execute_strng
# from Basics import control_flow
import Basics

def print_hi(name):
    # Use a breakpoint in the code line below to debug your script.
    print(f'Hi, {name}, Here is your script\n')  # Press Ctrl+F8 to toggle the breakpoint.
    print("Hi ")


# Press the green button in the gutter to run the script.
if __name__ == '__main__':
    print_hi('Mr. Lav')
    #Basics.execute_strng("Hello World","Awesome")
    #Basics.execute_list([3,2,1],['STRING',100,23.2])
    #Basics.execute_dict(d1={'key1':1, 'key2':2},d2={'k1':['hi','how','you'],'k2':'good'})
    #Basics.execute_tuples(t=(1,2,3))
    #Basics.execute_sets()
    #Basics.execute_operators()
    #Basics.control_flow(a=[(1,2),(3,4)], k={'k1':1,'k2': 2},b=(2,5),c=(2,8,2))
    Basics.execute_listcomprehension()


# See PyCharm help at https://www.jetbrains.com/help/pycharm/
# Out:
# Hi, Mr. Lav, Here is your script
#
#
# list comprehension
#
# String--> hello
# [mylist for mylist in str]--> ['h', 'e', 'l', 'l', 'o']
#
# Square of only even numbers in a list(0,11)
# [0, 4, 16, 36, 64, 100]
